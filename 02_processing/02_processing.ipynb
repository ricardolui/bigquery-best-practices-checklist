# %% [markdown]
# # BigQuery Best Practices: Processing & Performance
#
# **Objective:** Analyze the efficiency of your BigQuery workloads. We will look for queries that scan too much data (poor pruning), consume excessive resources (high slot usage), spill to disk (memory issues), or use common anti-patterns.
#
# **Contributors:**
# *   Google Cloud Data Analytics Team

# %%
# Initialize gcloud for authentication in the notebook
# # # # # # # # # # !gcloud auth application-default login  # Run manually in your terminal if needed  # Run manually in your terminal if needed  # Run manually in your terminal if needed  # Run manually in your terminal if needed  # Run manually in your terminal if needed  # Run manually in your terminal if needed  # Run manually in your terminal if needed  # Run manually in your terminal if needed  # Run manually in your terminal if needed

# %%
import pandas as pd
import bigframes.pandas as bpd
from google.cloud import bigquery
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize BigQuery Client
client = bigquery.Client()

# Configuration
PROJECT_ID = client.project  # Uses default project from environment
REGION = "us" # UPDATE THIS to your dataset region (e.g., eu, us-central1)
GEMINI_MODEL_NAME = "gemini-3.1-pro-preview" # Updated to use gemini-3.1-pro-preview
VERTEX_AI_LOCATION = "global" # Vertex AI location for Gemini models
GEMINI_ENDPOINT_URL = f"https://aiplatform.googleapis.com/v1/projects/{PROJECT_ID}/locations/{VERTEX_AI_LOCATION}/publishers/google/models/{GEMINI_MODEL_NAME}"

# Permission Fallback (True = use ORGANIZATION views, False = use scoped/aggregated metrics)
USE_ORGANIZATION_VIEWS = False

print(f"Project: {PROJECT_ID}")
print(f"Region: {REGION}")
print(f"Gemini Endpoint: {GEMINI_ENDPOINT_URL}")
print(f"Use Organization Views: {USE_ORGANIZATION_VIEWS}")
# Out:
# Project: dataml-latam-argolis
# Region: us
# Gemini Endpoint: https://aiplatform.googleapis.com/v1/projects/dataml-latam-argolis/locations/global/publishers/google/models/gemini-3.1-pro-preview
# Use Organization Views: False

# %% [markdown]
# ## 0. Prerequisites
#
# This section sets up the necessary prerequisites for the notebook.

# %% [markdown]
# ### 0.1. Create Gemini Model
#
# Create a BQML Remote Model that uses the Gemini model via DEFAULT connection for AI-powered recommendations.

# %%
create_model_sql = f"""
CREATE OR REPLACE MODEL `bq_best_practices_checklist.gemini`
REMOTE WITH CONNECTION DEFAULT
OPTIONS (endpoint = '{GEMINI_ENDPOINT_URL}')
"""


try:
    job = client.query(create_model_sql)
    job.result()
    print("Model created successfully.")
except Exception as e:
    print(f"Error creating model: {e}")
# Out:
# Model created successfully.

# %% [markdown]
# ### 0.2. Create Organization-level View
#
# Create a dataset and a view that aggregates jobs from the top 20 projects in the organization. This view will be used as the source for the subsequent analysis.

# %%
# First, ensure the schema exists
create_schema_query = f"CREATE SCHEMA IF NOT EXISTS `{PROJECT_ID}`.bq_best_practices_checklist OPTIONS(location='{REGION}');"
try:
    print(f"Attempting to create schema: {create_schema_query}")
    job = client.query(create_schema_query)
    job.result()
    print("Schema created or already exists successfully.")
except Exception as e:
    print(f"Error creating schema: {e}")
    # If schema creation fails, the view creation will also fail, so we might as well stop here.
    raise

# Then, create the view
setup_view_query = f'''
EXECUTE IMMEDIATE(
    SELECT
      'CREATE OR REPLACE VIEW `{PROJECT_ID}.bq_best_practices_checklist.jobs_by_top_20_projects` AS (' ||
      STRING_AGG(
        'SELECT * FROM `' || project_id || '.region-{REGION}.INFORMATION_SCHEMA.JOBS_BY_PROJECT`',
        ' UNION ALL '
      ) || ')'
    FROM (
      SELECT
        project_id
      FROM
        `region-{REGION}.INFORMATION_SCHEMA.JOBS_BY_ORGANIZATION`
      WHERE
        creation_time > TIMESTAMP_SUB(CURRENT_TIMESTAMP(), INTERVAL 30 DAY)
      GROUP BY
        1
      ORDER BY
        SUM(total_slot_ms) DESC
      LIMIT
        20
    )
);
'''

try:
    print(f"Attempting to create view.")
    job = client.query(setup_view_query)
    job.result()
    print("View created successfully.")
except Exception as e:
    print(f"Error creating view: {e}")
# Out:
# Attempting to create schema: CREATE SCHEMA IF NOT EXISTS `dataml-latam-argolis`.bq_best_practices_checklist OPTIONS(location='us');
# Schema created or already exists successfully.
# Attempting to create view.
# View created successfully.

# %% [markdown]
# ## 1. Pruning Efficiency
#
# **Objective:** Detect lack of partition filters.
# **Methodology:** Calculate the "Scan Efficiency Ratio" (Bytes Billed / Bytes Processed).
# **Success Criteria:** A ratio close to 1 is ideal. A high ratio (e.g., > 10) suggests the query is scanning far more data than it actually needs, often due to missing partition or clustering filters.

# %%
query_pruning = f"""
SELECT
  job_id,
  creation_time,
  user_email,
  total_bytes_billed,
  total_bytes_processed,
  SAFE_DIVIDE(total_bytes_processed, POW(1024, 3)) AS gib_processed,
  total_slot_ms,
  query
FROM
 `{PROJECT_ID}.bq_best_practices_checklist.jobs_by_top_20_projects`
WHERE
  creation_time > TIMESTAMP_SUB(CURRENT_TIMESTAMP(), INTERVAL 30 DAY)
  AND total_bytes_processed > 0
  AND job_type = 'QUERY'
  AND total_bytes_processed > 1024*1024*100 -- > 100MB
ORDER BY
  total_bytes_processed DESC
LIMIT 20
"""

df_pruning = client.query(query_pruning).to_dataframe()
print("Top 20 Queries by Bytes Processed (Partitioning/Clustering Candidates):")
df_pruning.head()
# Out:
# Top 20 Queries by Bytes Processed (Partitioning/Clustering Candidates):
#                                           job_id  \
# 0           d479dc34-c292-4ad8-b1bc-11d9a9a2b867
# 1  script_job_2c7ff3fcc4f580f909b8b9da46de45fa_1
# 2               job_xY3yYE-Lhx70M5CAiw3ijuE3Geyn
# 3               job_ftGkopIIFcIa3C8bXeqj87EK-Chb
# 4               job_9fa-M9IHuaDc2n1d1jWIZOM08gES
#
#                      creation_time                     user_email  \
# 0 2026-06-05 18:20:47.864000+00:00  leandroruiz@gcp.altostrat.com
# 1 2026-06-05 18:21:11.659000+00:00  leandroruiz@gcp.altostrat.com
# 2 2026-05-29 19:10:45.182000+00:00   admin@gricardo.altostrat.com
# 3 2026-05-29 19:42:39.397000+00:00   admin@gricardo.altostrat.com
# 4 2026-05-29 19:12:18.400000+00:00   admin@gricardo.altostrat.com
#
#    total_bytes_billed  total_bytes_processed  gib_processed  total_slot_ms  \
# 0         55494836224            55485008739      51.674441       31750547
# 1         55484350464            55483740523      51.673260       31642891
# 2         10655629312            10655572350       9.923775           4043
# 3         10655629312            10655572350       9.923775           3767
# 4          8951693312             8950680774       8.335971          16136
#
#                                                query
# 0  # Entrenamiento del modelo de Regresión Lineal...
# 1  CREATE OR REPLACE MODEL `bq-agents-globo._1c7c...
# 2  SELECT\n  COUNT(t.unique_key) AS total_trips\n...
# 3  SELECT\n    COUNT(taxi_trips.unique_key) AS to...
# 4  SELECT\n    COUNT(taxi_trips.unique_key) AS to...

# %% [markdown]
# **Recommendation:** Queries with high Scan Efficiency Ratio should be reviewed to ensure they use Partition/Clustering keys in the WHERE clause.

# %% [markdown]
# ## 2. Acceleration Candidates
#
# **Objective:** Identify queries that would benefit from **BigQuery Materialized Views** or **BI Engine**.
# **Methodology:** Look for repeated queries with high aggregation costs (Slot Time) relative to data size.
# **Success Criteria:** High-computation, repeated queries are moved to Materialized Views to save costs and improve latency.

# %%
query_acceleration = f"""
SELECT
  query_info.query_hashes.normalized_literals AS query_hash,
  COUNT(*) AS execution_count,
  AVG(total_slot_ms) AS avg_slot_ms,
  AVG(total_bytes_processed) AS avg_bytes_processed,
  SUM(total_slot_ms) / 1000 / 3600 AS total_slot_hours,
  ANY_VALUE(query) as sample_query
FROM
  `{PROJECT_ID}.bq_best_practices_checklist.jobs_by_top_20_projects`
WHERE
  creation_time > TIMESTAMP_SUB(CURRENT_TIMESTAMP(), INTERVAL 30 DAY)
  AND job_type = 'QUERY'
  AND cache_hit = FALSE
  -- Exclude DDL/DML statements
  AND NOT REGEXP_CONTAINS(UPPER(query), r'(CREATE\\s+OR\\s+REPLACE\\s+MODEL|CREATE\\s+TABLE|INSERT\\s+INTO|UPDATE\\s+|DELETE\\s+FROM|MERGE\\s+INTO)')
GROUP BY
  1
HAVING
  execution_count > 5 -- Repeated at least 5 times
ORDER BY
  total_slot_hours DESC
LIMIT 20
"""

df_acceleration = client.query(query_acceleration).to_dataframe()
print("Top Candidates for Acceleration (High Slot Usage & Repetition):")
df_acceleration.head()
# Out:
# Top Candidates for Acceleration (High Slot Usage & Repetition):
#                                           query_hash  execution_count  \
# 0  4b44c21e903158116cf9fe2e4df5decb1e8f75a07cfc55...             6574
# 1  43bc8eb163225908a7f5393ff0ef549d0a5f40428d1599...               33
# 2  af4dd4c32733b0fb69b614269d7dfc0c8e8f0d5db0f8a3...               40
# 3  59ac6952005af7ce04798210cc1c4afec943fdbb27cd46...               40
# 4  dc3bf299caef0f6bed343f857e27bdb2bfacda38d0aaf1...               40
#
#     avg_slot_ms  avg_bytes_processed  total_slot_hours  \
# 0    114.360207         1.048576e+07          0.208834
# 1  16290.696970         2.700780e+07          0.149331
# 2  13317.800000         5.395122e+07          0.147976
# 3   8002.525000         5.278186e+08          0.088917
# 4   7166.750000         2.044988e+08          0.079631
#
#                                         sample_query
# 0  SELECT property_graph_name AS analytic_model_n...
# 1  SELECT DISTINCT invoice.month FROM `dataml-lat...
# 2  \n    SELECT\n      invoice.month as invoice_m...
# 3  \n    SELECT\n      COALESCE(project.id, 'Non-...
# 4  \n    SELECT\n      COALESCE(project.id, 'Non-...

# %% [markdown]
# **Recommendation:** If 'execution_count' is high and 'avg_slot_ms' is significant, consider creating a Materialized View for the common aggregation logic.

# %% [markdown]
# ## 3. Spill-to-Disk Events
#
# **Objective:** Detect stages writing to disk, indicating memory issues.
# **Methodology:** Analyze `shuffle_output_bytes_spilled` in job stages.
# **Success Criteria:** Zero bytes spilled to disk. Spilling slows down queries significantly.
# **Remediation:** Adjust clustering keys to reduce shuffle size, or refactor logic (e.g., avoid massive `GROUP BY` on high-cardinality fields).

# %%
query_spill = f"""
SELECT
  job_id,
  creation_time,
  user_email,
  total_slot_ms,
  (SELECT SUM(shuffle_output_bytes_spilled) FROM UNNEST(job_stages)) / 1024 / 1024 / 1024 AS total_gb_spilled,
  query
FROM
 `{PROJECT_ID}.bq_best_practices_checklist.jobs_by_top_20_projects`
WHERE
  creation_time > TIMESTAMP_SUB(CURRENT_TIMESTAMP(), INTERVAL 30 DAY)
  AND EXISTS (SELECT 1 FROM UNNEST(job_stages) WHERE shuffle_output_bytes_spilled > 0)
ORDER BY
  total_gb_spilled DESC
LIMIT 20
"""

df_spill = client.query(query_spill).to_dataframe()
print("Top Queries with Spill-to-Disk Events:")
df_spill.head()
# Out:
# Top Queries with Spill-to-Disk Events:
# Empty DataFrame
# Columns: [job_id, creation_time, user_email, total_slot_ms, total_gb_spilled, query]
# Index: []

# %% [markdown]
# **Recommendation:** For queries spilling to disk, check if the JOIN keys or GROUP BY keys are skewed. Consider using INT64 keys instead of STRING where possible.

# %% [markdown]
# ## 4. Anti-Patterns
#
# **Objective:** Identify complex SQL anti-patterns using the BigQuery Anti-Pattern Recognition Tool.
# **Methodology:** Use the `get_antipatterns` UDF to analyze query text.
# **Prerequisite:** You must install the UDF in your project. Follow the instructions below.
#
# 1.  Clone the repository: `git clone https://github.com/GoogleCloudPlatform/bigquery-antipattern-recognition.git`
# 2.  Navigate to the Terraform directory: `cd bigquery-antipattern-recognition/udf/terraform`
# 3.  Initialize and apply Terraform: `terraform init && terraform apply`
#
# **Success Criteria:** Minimal occurrence of these patterns in production pipelines.

# %%
query_antipatterns = f"""
SELECT
  job_id,
  creation_time,
  user_email,
  query,
  `{PROJECT_ID}.fns.get_antipatterns`(query) AS anti_patterns
FROM
  `{PROJECT_ID}.bq_best_practices_checklist.jobs_by_top_20_projects`
WHERE
  creation_time > TIMESTAMP_SUB(CURRENT_TIMESTAMP(), INTERVAL 30 DAY)
  AND job_type = 'QUERY'
  -- Filter out simple queries or scripts if needed
LIMIT 100
"""

try:
    df_antipatterns = client.query(query_antipatterns).to_dataframe()
    # Filter rows where anti-patterns were found (assuming UDF returns null or empty list/struct for no matches)
    # Adjust filtering logic based on UDF actual return type
    print("Queries with Detected Anti-Patterns:")
    df_antipatterns.head()
except Exception as e:
    print("Error running Anti-Pattern query. Ensure the UDF is installed via Terraform.")
    print(e)
# Out:
# Queries with Detected Anti-Patterns:

# %% [markdown]
# **Recommendation:** Review the `anti_patterns` column for specific advice on how to optimize the query. Common issues include `SELECT *`, `ORDER BY` without `LIMIT`, and inefficient JOINs.

# %% [markdown]
# ## 5. Google Cloud Recommendations
#
# **Objective:** Review automated recommendations provided by Google Cloud for cost and performance optimization.
# **Methodology:** Query `INFORMATION_SCHEMA.RECOMMENDATIONS_BY_ORGANIZATION` to find potential slot and storage savings.
# **Success Criteria:** Regular review and application of high-impact recommendations.

# %%
query_recommendations = f"""
SELECT
  project_id,
  recommender,
  subtype,
  LAX_INT64(additional_details.overview.bytesSavedMonthly) / POW(1024, 3) as est_gb_saved_monthly,
  LAX_INT64(additional_details.overview.slotMsSavedMonthly) / (1000 * 3600) as slot_hours_saved_monthly,
  last_updated_time
FROM
 `region-{REGION}`.INFORMATION_SCHEMA.RECOMMENDATIONS_BY_ORGANIZATION
ORDER BY
  est_gb_saved_monthly DESC
LIMIT 20
"""

try:
    df_recommendations = client.query(query_recommendations).to_dataframe()
    print("Top Google Cloud Recommendations:")
    df_recommendations.head()
except Exception as e:
    print("Error querying Recommendations. Ensure you have the necessary permissions (Recommender Viewer) and the region is correct.", e)
    df_recommendations = pd.DataFrame() # Empty DF for summary
# Out:
# Top Google Cloud Recommendations:

# %% [markdown]
# **Recommendation:** Prioritize recommendations with high `est_gb_saved_monthly` or `slot_hours_saved_monthly`. Investigate the specific resources mentioned in the recommendation details.

# %% [markdown]
# ## 6. Query Execution Plan Analysis
# This check identifies jobs with wait-bound stages where `wait_ms_avg` exceeds `compute_ms_avg`, indicating slot contention or resource starvation.

# %%
# Identify inefficient query executions based on slot wait times and compute bottlenecks
source_table = f"`region-{REGION}`.INFORMATION_SCHEMA.JOBS_BY_ORGANIZATION" if USE_ORGANIZATION_VIEWS else f"`{PROJECT_ID}.bq_best_practices_checklist.jobs_by_top_20_projects`"

query = f"""
SELECT
  job_id,
  stage.name,
  stage.wait_ms_avg,
  stage.compute_ms_avg,
  stage.read_ms_avg,
  stage.write_ms_avg,
  stage.shuffle_output_bytes_spilled
FROM {source_table},
UNNEST(job_stages) AS stage
WHERE
  creation_time >= TIMESTAMP_SUB(CURRENT_TIMESTAMP(), INTERVAL 7 DAY)
  AND stage.wait_ms_avg > stage.compute_ms_avg  -- Wait-bound stages
  AND state = 'DONE'
ORDER BY stage.wait_ms_avg DESC
LIMIT 20;
"""
try:
    df_execution_plan = client.query(query).to_dataframe()
    display(df_execution_plan)
except Exception as e:
    print(f"Could not query execution plan metrics: {e}")
# Out:
#                                            job_id         name  wait_ms_avg  \
# 0   script_job_a2c63fb091fc6581e8be0a3b39415f1d_1  S03: Output         4099
# 1   script_job_a72c7ff338ff665323a74f99e299b87b_1  S03: Output         1896
# 2                job_D_YNLqIsA1FLQ54PXnds3Ji_cx7T  S00: Output         1000
# 3   script_job_7a78c0f8c8374509cf5559f2cc62802e_3  S03: Output          687
# 4                job_oWoR-sbvKeui5XBejWc976u7JT3B  S00: Output          564
# 5   script_job_5f00e52a02e9965307229a66271b241c_3  S03: Output          506
# 6                job_hateGQo9ML4-QQaaYECepQGgIdQW  S00: Output          502
# 7   script_job_2618345c20a7218431efffeba208bf7f_1  S03: Output          462
# 8   script_job_daca95eab696c51ccc828e5ec945623f_4  S03: Output          306
# 9                job_iJT-B1wEunmJpr83TIi8-um1CRjr  S00: Output          299
# 10  script_job_4df2f04ff8f4b6ad8d425f500d07d1ae_0  S03: Output          268
# 11  script_job_7670dff34ffedaaf4def2c219f12075a_0  S03: Output          252
# 12  script_job_c81b3077635b1b53f235edc2bcd12d3a_2  S03: Output          249
# 13  script_job_9183f3f8c171e965624f126ddec4c4f9_3  S03: Output          248
# 14  script_job_c822a9756283b4638b66675aed88feb0_4  S03: Output          247
# 15  script_job_ffe8810f62dae8c8da532ee4af95f46d_1  S03: Output          241
# 16  script_job_666f0b9efd39103c3eaf73c7e4675cbd_1  S03: Output          240
# 17               job_9ISU4nFGWEc0FWt09_KAL7c_N4sy  S00: Output          236
# 18  script_job_615f243b85dbdd31d0268dcaf1d66c47_2  S05: Output          236
# 19  script_job_abe61bca48f505a18d9bffd9980622f5_2  S09: Output          236
#
#     compute_ms_avg  read_ms_avg  write_ms_avg  shuffle_output_bytes_spilled
# 0               15            0           139                             0
# 1               18            0           136                             0
# 2               19            0             2                             0
# 3               23            0           178                             0
# 4               14            0             3                             0
# 5               21            0           143                             0
# 6               20            0             4                             0
# 7               17            0           171                             0
# 8               79            0           161                             0
# 9               31            0             3                             0
# 10              40            0           187                             0
# 11              31            0           240                             0
# 12              26            0           171                             0
# 13              20            0           172                             0
# 14              41            0           176                             0
# 15              38            0           191                             0
# 16              21            0           343                             0
# 17              17            0             3                             0
# 18              30            0           141                             0
# 19              52            0           181                             0

# %% [markdown]
# ## 7. Vector Search / BQML Efficiency
# Check for BQML usage and Vector Search indexing. Ensure vector indexes are created and used appropriately for vector distance operations.

# %%
# Identify usage of VECTOR_SEARCH and potential missing indexes
source_table = f"`region-{REGION}`.INFORMATION_SCHEMA.JOBS_BY_ORGANIZATION" if USE_ORGANIZATION_VIEWS else f"`{PROJECT_ID}.bq_best_practices_checklist.jobs_by_top_20_projects`"

query = f"""
SELECT
  project_id, job_id, user_email, creation_time,
  total_bytes_processed,
  total_slot_ms,
  TIMESTAMP_DIFF(end_time, start_time, MILLISECOND) AS duration_ms,
  query
FROM {source_table}
WHERE
  creation_time >= TIMESTAMP_SUB(CURRENT_TIMESTAMP(), INTERVAL 7 DAY)
  AND REGEXP_CONTAINS(UPPER(query), 'VECTOR_SEARCH')
  AND state = 'DONE'
ORDER BY total_slot_ms DESC
LIMIT 10;
"""
try:
    df_vector_search = client.query(query).to_dataframe()
    display(df_vector_search)
except Exception as e:
    print(f"Could not query vector search metrics: {e}")
# Out:
#              project_id                                job_id  \
# 0  dataml-latam-argolis  201abf73-ef92-4a9c-a89b-177da9342ed9
# 1  dataml-latam-argolis  6511f329-8fa0-4bcd-ba5c-a57ddcb85445
#
#                      user_email                    creation_time  \
# 0  admin@gricardo.altostrat.com 2026-06-17 19:29:07.993000+00:00
# 1  admin@gricardo.altostrat.com 2026-06-17 19:29:24.189000+00:00
#
#    total_bytes_processed  total_slot_ms  duration_ms  \
# 0               62643080          98253         4727
# 1                      0           <NA>          350
#
#                                                query
# 0  \nSELECT\n  project_id, job_id, user_email, cr...
# 1  ALTER SCHEMA `dataml-latam-argolis.vector_sear...

# %% [markdown]
# ## 8. AI-Powered Recommendations
#
# **Objective:** Use Generative AI to synthesize the findings and provide actionable advice.
# **Methodology:** Summarize the dataframes above and pass them to a Gemini Pro model via BQML.

# %%
# Note: Model creation is already handled in Section 0.1 using the parameterized GEMINI_ENDPOINT_URL.
# This cell is kept for reference but should use the model created above.
print("Gemini model already created in Section 0.1. Skipping duplicate creation.")
# Out:
# Gemini model already created in Section 0.1. Skipping duplicate creation.

# %%
# Summarize findings for Gemini
summary_text = f'''
Audit Findings for Processing Layer & Performance:
1. Pruning Efficiency: Found {len(df_pruning)} queries with poor scanning efficiency (high Bytes Billed / Bytes Processed).
2. Acceleration: Identified {len(df_acceleration)} repeated heavy queries suitable for Materialized Views.
3. Spills: Detected {len(df_spill)} queries spilling to disk (memory pressure).
4. Anti-Patterns: Flagged {len(df_antipatterns)} queries with anti-patterns (using Anti-Pattern Recognition Tool).
5. Google Cloud Recommendations: Found {len(df_recommendations)} active recommendations from the platform.
'''

# Construct the prompt
prompt = f"Analyze the following metrics regarding Processing Layer & Performance and provide 3 actionable recommendations on topic Processing Layer & Performance. Context: {summary_text}"

# Call Gemini via BQML
query_gemini = f"""
SELECT
  ml_generate_text_result['candidates'][0]['content'] AS recommendation
FROM
  ML.GENERATE_TEXT(
    MODEL `{PROJECT_ID}.bq_best_practices_checklist.gemini`,
    (SELECT '''{prompt.replace("'", "''")}''' AS prompt),
    STRUCT(
      0.2 AS temperature,
      8192 AS max_output_tokens
    )
  )
"""

try:
    df_gemini = client.query(query_gemini).to_dataframe()
    print("Gemini Recommendations:")
    print(df_gemini['recommendation'].iloc[0])
except Exception as e:
    print("Error calling Gemini Model (Ensure Model and Connection exist):", e)
    print("Prompt used:", prompt)
# Out:
# Gemini Recommendations:
# {"parts":[{"text":"### Analysis of Processing Layer & Performance Metrics\n\nOverall, your processing layer shows excellent memory management (0 disk spills) and a clean bill of health from automated Google Cloud platform recommendations. However, there are significant inefficiencies in how data is being queried and accessed. The presence of poor pruning efficiency, repeated heavy queries, and a high volume of query anti-patterns indicates that while the infrastructure is stable, **query logic and data retrieval strategies are driving up unnecessary compute costs and degrading performance.**\n\nHere are 3 actionable recommendations to address these specific findings:\n\n### 1. Enforce Partitioning and Clustering to Fix Pruning Efficiency\n**Context:** The 20 queries with poor scanning efficiency (high Bytes Billed vs. Bytes Processed) indicate that queries are performing full table scans rather than targeting specific subsets of data. This is a primary driver of inflated cloud costs.\n**Actionable Steps:**\n*   **Analyze the 20 Queries:** Identify the underlying tables these queries are hitting. Check if those tables are partitioned (e.g., by date/timestamp) and clustered by frequently filtered columns.\n*   **Enforce Partition Filters:** For the heavily queried tables, toggle on the `Require Partition Filter` setting. This will force users to include a `WHERE` clause on the partitioned column, preventing accidental full-table scans.\n*   **Refactor `SELECT *`:** Ensure these queries are only selecting the specific columns needed for their output, rather than scanning the entire columnar structure.\n\n### 2. Deploy Materialized Views for the Repeated Heavy Queries\n**Context:** Executing the same 20 heavy queries repeatedly is a massive waste of compute resources and increases latency for end-users (like BI dashboards). \n**Actionable Steps:**\n*   **Create Materialized Views (MVs):** Translate the logic of these 20 heavy queries into Materialized Views. The database will pre-compute and store the results, updating them incrementally as base data changes.\n*   **Reroute Downstream Assets:** Update your BI tools, dashboards, or downstream data pipelines to point to the newly created MVs instead of querying the raw base tables.\n*   **Monitor Smart Tuning:** Leverage the platform's smart tuning capabilities (if applicable in your specific data warehouse) so that even if users query the base tables, the engine automatically routes the query to the MV behind the scenes.\n\n### 3. Establish a Remediation and Training Program for Query Anti-Patterns\n**Context:** Flagging 100 queries with anti-patterns reveals a systemic issue in how your analysts or engineers are writing SQL. Common anti-patterns include cross-joins, using functions on joined columns (which breaks indexing), or filtering on non-indexed string manipulations.\n**Actionable Steps:**\n*   **Triage and Refactor:** Sort the 100 flagged queries by execution cost/frequency. Assign data engineers to immediately rewrite the top 20 most expensive queries to eliminate the anti-patterns.\n*   **Implement CI/CD Guardrails:** Integrate a SQL linter or an automated anti-pattern recognition tool into your code deployment pipeline (e.g., GitHub Actions) to block new queries with anti-patterns from being pushed to production.\n*   **Conduct Team Training:** Group the 100 anti-patterns by category to identify the most common mistakes. Hold a targeted training session for your data consumers on \"Query Best Practices\" to address these specific bad habits.","thought_signature":"..."}],"role":"model"}
